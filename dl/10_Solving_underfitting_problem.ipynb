# %% [markdown]
# # 실전 문제 해결 (과소적합)

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## 하이퍼 파라미터

# %%
EPOCHS = 100

# %% [markdown]
# ## 모델 정의

# %%
class MyModel(tf.keras.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.flatten = tf.keras.layers.Flatten()
        self.dense1 = tf.keras.layers.Dense(32, use_bias=False)
        self.batch1 = tf.keras.layers.BatchNormalization()
        
        self.batch2 = tf.keras.layers.BatchNormalization()
        self.dense2 = tf.keras.layers.Dense(32, use_bias=False)
        
        self.batch3 = tf.keras.layers.BatchNormalization()
        self.dense3 = tf.keras.layers.Dense(64, use_bias=False)
        
        self.batch4 = tf.keras.layers.BatchNormalization()
        self.dense4 = tf.keras.layers.Dense(128, use_bias=False)
        
        self.dense5 = tf.keras.layers.Dense(10, activation='softmax')

    def call(self, x, training=False, mask=None):
        x = self.flatten(x)
        
        x = self.dense1(x)
        x = self.batch1(x, training)
        x = tf.nn.relu(x)
        
        h = self.batch2(x, training)
        h = tf.nn.relu(h)
        h = self.dense2(h)
        x = tf.concat([x, h], axis=-1)
        
        h = self.batch3(x, training)
        h = tf.nn.relu(h)
        h = self.dense3(h)
        x = tf.concat([x, h], axis=-1)
        
        h = self.batch4(x, training)
        h = tf.nn.relu(h)
        h = self.dense4(h)
        x = tf.concat([x, h], axis=-1)

        return self.dense5(x)

# %% [markdown]
# ## 데이터셋 준비

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist # 28x28  -> 10 class

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(10000).batch(32).prefetch(2048)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(32).prefetch(2048)

# %% [markdown]
# ## Keras API 모델 학습

# %%
model = MyModel()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_ds, validation_data=test_ds, epochs=EPOCHS)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.5182 - accuracy: 0.8151 - val_loss: 0.4462 - val_accuracy: 0.8426
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3985 - accuracy: 0.8535 - val_loss: 0.4238 - val_accuracy: 0.8578
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3636 - accuracy: 0.8665 - val_loss: 0.3799 - val_accuracy: 0.8636
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3448 - accuracy: 0.8725 - val_loss: 0.3987 - val_accuracy: 0.8580
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3294 - accuracy: 0.8770 - val_loss: 0.3903 - val_accuracy: 0.8650
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3174 - accuracy: 0.8827 - val_loss: 0.3548 - val_accuracy: 0.8682
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3082 - accuracy: 0.8853 - val_loss: 0.3858 - val_accuracy: 0.8621
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2957 - accuracy: 0.8896 - val_loss: 0.3819 - val_accuracy: 0.8634
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2902 - accuracy: 0.8918 - val_loss: 0.3597 - val_accuracy: 0.8748
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2839 - accuracy: 0.8936 - val_loss: 0.3709 - val_accuracy: 0.8708
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2782 - accuracy: 0.8956 - val_loss: 0.3502 - val_accuracy: 0.8765
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2739 - accuracy: 0.8966 - val_loss: 0.3913 - val_accuracy: 0.8697
# Epoch 13/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2681 - accuracy: 0.8997 - val_loss: 0.3987 - val_accuracy: 0.8604
# Epoch 14/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2652 - accuracy: 0.9004 - val_loss: 0.3595 - val_accuracy: 0.8768
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2588 - accuracy: 0.9040 - val_loss: 0.3970 - val_accuracy: 0.8660
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2538 - accuracy: 0.9047 - val_loss: 0.3572 - val_accuracy: 0.8785
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2497 - accuracy: 0.9064 - val_loss: 0.3615 - val_accuracy: 0.8757
# Epoch 18/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2481 - accuracy: 0.9067 - val_loss: 0.3607 - val_accuracy: 0.8788
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2449 - accuracy: 0.9077 - val_loss: 0.3542 - val_accuracy: 0.8800
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2415 - accuracy: 0.9093 - val_loss: 0.3827 - val_accuracy: 0.8735
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2351 - accuracy: 0.9123 - val_loss: 0.3698 - val_accuracy: 0.8782
# Epoch 22/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2371 - accuracy: 0.9108 - val_loss: 0.3704 - val_accuracy: 0.8793
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2330 - accuracy: 0.9117 - val_loss: 0.3717 - val_accuracy: 0.8736
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2284 - accuracy: 0.9139 - val_loss: 0.3897 - val_accuracy: 0.8740
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2278 - accuracy: 0.9150 - val_loss: 0.4067 - val_accuracy: 0.8711
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2257 - accuracy: 0.9137 - val_loss: 0.3836 - val_accuracy: 0.8754
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2247 - accuracy: 0.9155 - val_loss: 0.3523 - val_accuracy: 0.8842
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2205 - accuracy: 0.9171 - val_loss: 0.3630 - val_accuracy: 0.8765
# Epoch 29/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2208 - accuracy: 0.9159 - val_loss: 0.3759 - val_accuracy: 0.8822
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2178 - accuracy: 0.9192 - val_loss: 0.3780 - val_accuracy: 0.8784
# Epoch 31/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2144 - accuracy: 0.9191 - val_loss: 0.4553 - val_accuracy: 0.8584
# Epoch 32/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2144 - accuracy: 0.9190 - val_loss: 0.3788 - val_accuracy: 0.8715
# Epoch 33/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2121 - accuracy: 0.9201 - val_loss: 0.3662 - val_accuracy: 0.8840
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2075 - accuracy: 0.9219 - val_loss: 0.3738 - val_accuracy: 0.8756
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2096 - accuracy: 0.9209 - val_loss: 0.3822 - val_accuracy: 0.8754
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2096 - accuracy: 0.9199 - val_loss: 0.3863 - val_accuracy: 0.8764
# Epoch 37/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2069 - accuracy: 0.9209 - val_loss: 0.3674 - val_accuracy: 0.8792
# Epoch 38/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2056 - accuracy: 0.9224 - val_loss: 0.3787 - val_accuracy: 0.8750
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2029 - accuracy: 0.9219 - val_loss: 0.3742 - val_accuracy: 0.8787
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2008 - accuracy: 0.9238 - val_loss: 0.3712 - val_accuracy: 0.8846
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1996 - accuracy: 0.9250 - val_loss: 0.3909 - val_accuracy: 0.8786
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2001 - accuracy: 0.9235 - val_loss: 0.3735 - val_accuracy: 0.8831
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1991 - accuracy: 0.9242 - val_loss: 0.3753 - val_accuracy: 0.8789
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1959 - accuracy: 0.9264 - val_loss: 0.4050 - val_accuracy: 0.8719
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1952 - accuracy: 0.9262 - val_loss: 0.4027 - val_accuracy: 0.8719
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1958 - accuracy: 0.9250 - val_loss: 0.3811 - val_accuracy: 0.8828
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1916 - accuracy: 0.9276 - val_loss: 0.3707 - val_accuracy: 0.8858
# Epoch 48/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1926 - accuracy: 0.9282 - val_loss: 0.3854 - val_accuracy: 0.8818
# Epoch 49/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1925 - accuracy: 0.9275 - val_loss: 0.4021 - val_accuracy: 0.8782
# Epoch 50/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1881 - accuracy: 0.9288 - val_loss: 0.4238 - val_accuracy: 0.8750
# Epoch 51/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1884 - accuracy: 0.9280 - val_loss: 0.3812 - val_accuracy: 0.8822
# Epoch 52/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1874 - accuracy: 0.9294 - val_loss: 0.3878 - val_accuracy: 0.8799
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1849 - accuracy: 0.9305 - val_loss: 0.4326 - val_accuracy: 0.8735
# Epoch 54/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1843 - accuracy: 0.9311 - val_loss: 0.3957 - val_accuracy: 0.8797
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1824 - accuracy: 0.9308 - val_loss: 0.4361 - val_accuracy: 0.8737
# Epoch 56/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1835 - accuracy: 0.9305 - val_loss: 0.4082 - val_accuracy: 0.8802
# Epoch 57/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1853 - accuracy: 0.9303 - val_loss: 0.3970 - val_accuracy: 0.8774
# Epoch 58/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1809 - accuracy: 0.9311 - val_loss: 0.4006 - val_accuracy: 0.8806
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1803 - accuracy: 0.9323 - val_loss: 0.4003 - val_accuracy: 0.8793
# Epoch 60/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1831 - accuracy: 0.9290 - val_loss: 0.3907 - val_accuracy: 0.8823
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1779 - accuracy: 0.9329 - val_loss: 0.4158 - val_accuracy: 0.8781
# Epoch 62/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1812 - accuracy: 0.9317 - val_loss: 0.4028 - val_accuracy: 0.8806
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1804 - accuracy: 0.9309 - val_loss: 0.4105 - val_accuracy: 0.8803
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1760 - accuracy: 0.9325 - val_loss: 0.4036 - val_accuracy: 0.8812
# Epoch 65/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1733 - accuracy: 0.9336 - val_loss: 0.4049 - val_accuracy: 0.8774
# Epoch 66/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1752 - accuracy: 0.9340 - val_loss: 0.4514 - val_accuracy: 0.8760
# Epoch 67/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1742 - accuracy: 0.9336 - val_loss: 0.4103 - val_accuracy: 0.8775
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1762 - accuracy: 0.9336 - val_loss: 0.4178 - val_accuracy: 0.8781
# Epoch 69/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1714 - accuracy: 0.9350 - val_loss: 0.4026 - val_accuracy: 0.8811
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1722 - accuracy: 0.9355 - val_loss: 0.4090 - val_accuracy: 0.8802
# Epoch 71/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1717 - accuracy: 0.9348 - val_loss: 0.4285 - val_accuracy: 0.8747
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1718 - accuracy: 0.9354 - val_loss: 0.4243 - val_accuracy: 0.8769
# Epoch 73/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1678 - accuracy: 0.9350 - val_loss: 0.4282 - val_accuracy: 0.8769
# Epoch 74/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1697 - accuracy: 0.9363 - val_loss: 0.4224 - val_accuracy: 0.8772
# Epoch 75/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1695 - accuracy: 0.9365 - val_loss: 0.4193 - val_accuracy: 0.8815
# Epoch 76/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1682 - accuracy: 0.9369 - val_loss: 0.4332 - val_accuracy: 0.8740
# Epoch 77/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1650 - accuracy: 0.9368 - val_loss: 0.4407 - val_accuracy: 0.8769
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1647 - accuracy: 0.9385 - val_loss: 0.4378 - val_accuracy: 0.8818
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1641 - accuracy: 0.9380 - val_loss: 0.4286 - val_accuracy: 0.8817
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1649 - accuracy: 0.9373 - val_loss: 0.4311 - val_accuracy: 0.8729
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1637 - accuracy: 0.9377 - val_loss: 0.4462 - val_accuracy: 0.8728
# Epoch 82/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1628 - accuracy: 0.9381 - val_loss: 0.4609 - val_accuracy: 0.8769
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1642 - accuracy: 0.9383 - val_loss: 0.4333 - val_accuracy: 0.8785
# Epoch 84/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1607 - accuracy: 0.9396 - val_loss: 0.4427 - val_accuracy: 0.8722
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1634 - accuracy: 0.9366 - val_loss: 0.4378 - val_accuracy: 0.8771
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1598 - accuracy: 0.9392 - val_loss: 0.4420 - val_accuracy: 0.8738
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1616 - accuracy: 0.9381 - val_loss: 0.4345 - val_accuracy: 0.8729
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1591 - accuracy: 0.9397 - val_loss: 0.4465 - val_accuracy: 0.8786
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1593 - accuracy: 0.9393 - val_loss: 0.4333 - val_accuracy: 0.8773
# Epoch 90/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1581 - accuracy: 0.9399 - val_loss: 0.4490 - val_accuracy: 0.8766
# Epoch 91/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1595 - accuracy: 0.9389 - val_loss: 0.4411 - val_accuracy: 0.8826
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1591 - accuracy: 0.9392 - val_loss: 0.4496 - val_accuracy: 0.8751
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1579 - accuracy: 0.9405 - val_loss: 0.4402 - val_accuracy: 0.8809
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1538 - accuracy: 0.9421 - val_loss: 0.4496 - val_accuracy: 0.8806
# Epoch 95/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1523 - accuracy: 0.9415 - val_loss: 0.4799 - val_accuracy: 0.8746
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1573 - accuracy: 0.9406 - val_loss: 0.4751 - val_accuracy: 0.8704
# Epoch 97/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1576 - accuracy: 0.9394 - val_loss: 0.4444 - val_accuracy: 0.8807
# Epoch 98/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1567 - accuracy: 0.9410 - val_loss: 0.4752 - val_accuracy: 0.8682
# Epoch 99/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1551 - accuracy: 0.9405 - val_loss: 0.4419 - val_accuracy: 0.8766
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1554 - accuracy: 0.9421 - val_loss: 0.4712 - val_accuracy: 0.8758
